# %%
# load in District 2024 keys table raw and post cleaning

# %%
# Compute Levenshtein distance (edit distance) of NAME column values

# %%
# Compute t-SNE of the NAME edit distance matrix

# %%
# Do some person correlation or something similar for the LABEL column

# %%
# using the vector I get from this preform some soft clustering algorithm

# %%
# If we have 4 dimensions to plot figure out the magnitude "gravity" something like that of which ever dimension is being used as the 4th

# %%
# Plot on a scatter plot
